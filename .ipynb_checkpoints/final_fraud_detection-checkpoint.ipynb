# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('fraud_detection.csv')
data.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
data.shape
data.columns
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110813 entries, 0 to 110812
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            110813 non-null  int64
#  1   type            110813 non-null  object
#  2   amount          110813 non-null  float64
#  3   nameOrig        110813 non-null  object
#  4   oldbalanceOrg   110813 non-null  float64
#  5   newbalanceOrig  110813 non-null  float64
#  6   nameDest        110813 non-null  object
#  7   oldbalanceDest  110813 non-null  float64
#  8   newbalanceDest  110812 non-null  float64
#  9   isFraud         110812 non-null  float64
#  10  isFlaggedFraud  110812 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 9.3+ MB
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  110813.000000  1.108130e+05   1.108130e+05    1.108130e+05
# ...

# %%
obj = (data.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:", len(object_cols))
# Out:
# Categorical variables: 3

# %%
int_ = (data.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:", len(num_cols))
# Out:
# Integer variables: 1

# %%
fl = (data.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:", len(fl_cols))
# Out:
# Float variables: 7

# %%
data.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
data[['oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']] = data[['oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']].fillna(0)
data['nameDest'] = data['nameDest'].fillna('Unknown')
data['isFraud'] = data['isFraud'].fillna(data['isFraud'].mode()[0])
data['isFlaggedFraud'] = data['isFlaggedFraud'].fillna(data['isFlaggedFraud'].mode()[0])

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
numeric_cols = ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']

# %%
plt.figure(figsize=(15, 8))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=data[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel('')
plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data[col] = data[col].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

for col in numeric_cols:
    plt.figure(figsize=(5, 5))
    sns.boxplot(x=data[col])
    plt.title(f'Capped Boxplot of {col}')
    plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(np.log1p(data['amount']), bins=100, kde=True)
plt.title('Log-Scaled Distribution of Transaction Amounts')
plt.xlabel('Log(Amount + 1)')
plt.ylabel('Frequency')
plt.show()

# %%
data['hour'] = data['step'] % 24
plt.figure(figsize=(10, 5))
sns.countplot(x='hour', hue='isFraud', data=data)
plt.title('Fraudulent vs Non-Fraudulent Transactions by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Transaction Count')
plt.legend(title='isFraud')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=data, x='amount', hue='isFraud', bins=50, kde=True, palette={0:'blue',1:'red'}, alpha=0.6)
plt.title('Transaction Amount Distribution: Fraud vs Non-Fraud')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.legend(title='Is Fraud', labels=['Legit','Fraud'])
plt.show()

# %%
data['amount_norm'] = data['amount'] / (data.groupby('nameOrig')['amount'].transform('mean') + 1e-6)
plt.figure(figsize=(10,5))
sns.histplot(data['amount_norm'], bins=50, kde=True, color='purple', alpha=0.6)
plt.title('Normalized Transaction Amount per Sender')
plt.xlabel('Amount / Average Amount (Sender)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='type', data=data)
plt.title('Transaction Type Distribution')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='isFraud', data=data)
plt.title('Fraudulent vs Non-Fraudulent Transactions')
plt.xlabel('isFraud (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='type', y='amount', data=data)
plt.title('Transaction Amounts by Type')
plt.xlabel('Transaction Type')
plt.ylabel('Amount')
plt.show()

# %%
fraud_rate = data.groupby('type')['isFraud'].mean().reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(x='type', y='isFraud', data=fraud_rate)
plt.title('Average Fraud Rate by Transaction Type')
plt.ylabel('Fraud Rate')
plt.xlabel('Transaction Type')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='isFraud', y='amount', data=data)
plt.title('Transaction Amounts by Fraud Status')
plt.xlabel('isFraud (0 = No, 1 = Yes)')
plt.ylabel('Amount')
plt.yscale('log')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.apply(lambda x: pd.factorize(x)[0]).corr(),
cmap='coolwarm',
fmt='.2f',
linewidths=2,
annot=True)
# Out:
# <Axes: >

# %%
sample = data.sample(3000, random_state=42)
sns.pairplot(sample, vars=['amount', 'oldbalanceOrg', 'newbalanceOrig'], hue='isFraud', plot_kws={'alpha': 0.5})
plt.suptitle('Pairwise Feature Relationships by Fraud Status', y=1.02)
plt.show()

# %%
# Data Preprocessing
data['error_org'] = data['oldbalanceOrg'] - data['newbalanceOrig'] - data['amount']
data['error_dest'] = data['newbalanceDest'] - data['oldbalanceDest'] - data['amount']
data['balance_diff_org'] = data['newbalanceOrig'] - data['oldbalanceOrg']
data['balance_diff_dest'] = data['newbalanceDest'] - data['oldbalanceDest']
data['ratio_org'] = data['newbalanceOrig'] / (data['oldbalanceOrg'] + 1)
data['ratio_dest'] = data['newbalanceDest'] / (data['oldbalanceDest'] + 1)

# %%
type_new = pd.get_dummies(data['type'], drop_first=True)
data_new = pd.concat([data, type_new], axis=1)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['error_org'], bins=50, kde=True)
plt.title('Error in Sender Balance')
plt.xlabel('Error (Sender)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['error_dest'], bins=50, kde=True)
plt.title('Error in Receiver Balance')
plt.xlabel('Error (Receiver)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data['ratio_org'], bins=20, kde=True, color='blue', label='Sender')
sns.histplot(data['ratio_dest'], bins=20, kde=True, color='orange', label='Receiver', alpha=0.6)
plt.title('Ratio of New to Old Balance: Sender vs Receiver')
plt.xlabel('Balance Ratio')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# ---- Import ML Libraries ----
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score as ras
from imblearn.over_sampling import SMOTE

# %%
# ---- Step 1: Additional Feature ----
data_new['log_amount'] = np.log1p(data_new['amount'])

# %%
# ---- Step 2: Select Features ----
X = data_new.drop(['isFraud', 'type', 'nameOrig', 'nameDest'], axis=1)
y = data_new['isFraud']

print("Feature shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Feature shape: (110813, 20)
# Target shape: (110813,)

# %%
# ---- Step 3: Scale Selected Columns ----
scale_cols = ['amount', 'oldbalanceOrg', 'newbalanceOrig',
              'oldbalanceDest', 'newbalanceDest', 'log_amount']

# %%
scaler = StandardScaler()
X[scale_cols] = scaler.fit_transform(X[scale_cols])

# %%
# ---- Step 4: Handle Class Imbalance ----
X_res, y_res = SMOTE(k_neighbors=5, random_state=42).fit_resample(X, y)

# %%
# ---- Step 5: Train-Test Split ----
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.3, random_state=42
)

# %%
# ---- Step 6: Prepare Scaled Data for Logistic Regression ----
scaler_full = StandardScaler()
X_train_scaled = scaler_full.fit_transform(X_train)
X_test_scaled = scaler_full.transform(X_test)

# %%
# ---- Step 7: Define Models ----
log_model = LogisticRegression(max_iter=1000)

rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=4,
    min_samples_leaf=20,
    max_features='sqrt',
    max_samples=0.8,
    criterion='entropy',
    random_state=7
)

# %%
# ---- Step 8: Train & Evaluate ----
models = [log_model, rf_model]
model_names = ['Logistic Regression', 'Random Forest']

for model, name in zip(models, model_names):
    print(f"\n{name}")

    if name == 'Logistic Regression':
        model.fit(X_train_scaled, y_train)
        train_preds = model.predict_proba(X_train_scaled)[:, 1]
        test_preds = model.predict_proba(X_test_scaled)[:, 1]
    else:
        model.fit(X_train, y_train)
        train_preds = model.predict_proba(X_train)[:, 1]
        test_preds = model.predict_proba(X_test)[:, 1]

    train_score = ras(y_train, train_preds)
    test_score = ras(y_test, test_preds)

    print(f"Training AUC: {train_score:.4f}")
    print(f"Validation AUC: {test_score:.4f}")
    print(f"Generalization Gap: {train_score - test_score:.4f}")
    print("-" * 40)
# Out:
# Logistic Regression
# Training AUC: 0.9933
# Validation AUC: 0.9930
# Generalization Gap: 0.0003
# ----------------------------------------
#
# Random Forest
# Training AUC: 0.9988
# Validation AUC: 0.9989
# Generalization Gap: -0.0001
# ----------------------------------------

# %%
import joblib

# Save the best model (Random Forest)
joblib.dump(rf_model, "rf_fraud_model.pkl")

print("\n Random Forest model saved successfully")
# Out:
#  Random Forest model saved successfully
